# %% [markdown]
# # Homework - Neural networks - Part B (55 points)
# ## Gradient descent for simple two and three layer models

# %% [markdown]
# by *Brenden Lake* and *Todd Gureckis*
# Computational Cognitive Modeling
# NYU class webpage: https://brendenlake.github.io/CCM-site/

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# This homework is due before midnight on Monday, Feb. 13, 2023.
# </div>

# %% [markdown]
# The first part of this assignment implements the gradient descent algorithm for a simple artificial neuron. The second part implements backpropagation for a simple network with one hidden unit.
#
# In the first part, the neuron will learn to compute logical OR. The neuron model and logical OR are shown below, for inputs $x_0$ and $x_1$ and target output $y$.
#
# <img src="images/nn_OR.jpeg" style="width: 350px;"/>
#
# This assignment requires some basic PyTorch knowledge. You can review your notes from lab and this [PyTorch tutorial](https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html). The "Introduction to PyTorch" section on the PyTorch website is also helpful.

# %%
# Import libraries
from __future__ import print_function
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import torch

# %% [markdown]
# Let's create `torch.tensor` objects for representing the data matrix `X` with targets `Y_or` (for the logical OR function). Each row of `X` is a different input pattern.

# %%
X_list = [[0.,0.], [0.,1.], [1.,0.], [1.,1.]]
X = torch.tensor(X_list)
Y_or = torch.tensor([0.,1.,1.,1.])
N = X.shape[0] # number of input patterns
print("Input tensor X:")
print('  has shape',X.shape)
print('  and contains',X)
print('Target tensor Y:')
print('  has shape',Y_or.shape)
print('  and contains',Y_or)
# Out:
# Input tensor X:
#   has shape torch.Size([4, 2])
#   and contains tensor([[0., 0.],
#         [0., 1.],
#         [1., 0.],
#         [1., 1.]])
# Target tensor Y:
#   has shape torch.Size([4])
#   and contains tensor([0., 1., 1., 1.])

# %% [markdown]
# The artificial neuron operates as follows. Given an input vector $x$ (which is one row of input tensor $X$), the net input ($\textbf{net}$) to the neuron is computed as follows
#
# $$ \textbf{net} = \sum_i x_i w_i + b,$$
#
# for weights $w_i$ and bias $b$. The activation function $g(\textbf{net})$ is the logistic function
#
# $$ g(\textbf{net}) = \frac{1}{1+e^{-\textbf{net}}},$$
#
# which is used to compute the predicted output $\hat{y} = g(\textbf{net})$. Finally, the loss (squared error) for a particular pattern $x$ is defined as
#
# $$ E(w,b) = (\hat{y}-y)^2,$$
#
# where the target output is $y$. **Your main task is to manually compute the gradients of the loss $E$ with respect to the neuron parameters:**
#
# $$\frac{\partial E(w,b)}{\partial w}, \frac{\partial E(w,b)}{\partial b}.$$
#
# By manually, we mean to program the gradient computation directly, using the formulas discussed in class. This is in contrast to using PyTorch's `autograd` (Automatric differentiation) that computes the gradient automatically, as discussed in class, lab, and in the PyTorch tutorial (e.g., `loss.backward()`). First, let's write the activation function and the loss in PyTorch.

# %%
def g_logistic(net):
    return 1. / (1.+torch.exp(-net))

def loss(yhat,y):
    return (yhat-y)**2

# %% [markdown]
# Next, we'll also write two functions for examining the internal operations of the neuron, and the gradients of its parameters.

# %%
def print_forward(x,yhat,y):
    # Examine network's prediction for input x
    print(' Input: ',end='')
    print(x.numpy())
    print(' Output: ' + str(round(yhat.item(),3)))
    print(' Target: ' + str(y.item()))

def print_grad(grad_w,grad_b):
    # Examine gradients
    print('  d_loss / d_w = ',end='')
    print(grad_w)
    print('  d_loss / d_b = ',end='')
    print(grad_b)

# %% [markdown]
# Now let's dive in and begin the implementation of stochastic gradient descent. We'll initialize our parameters $w$ and $b$ randomly, and proceed through a series of epochs of training. Each epoch involves visiting the four training patterns in random order, and updating the parameters after each presentation of an input pattern.

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <h3> Problem 1 (10 points) </h3>
# <br>
# In the code below, fill in code to manually compute the gradient in closed form.
#     <ul>
#         <li>See lecture slides for the equation for the gradient for the weights w.</li>
#         <li>Derive (or reason) to get the equation for the gradient for bias b.</li>
#     </ul>
# </div>
#
# <div class="alert alert-success" role="alert">
# <h3> Problem 2 (5 points) </h3>
# <br>
# In the code below, fill in code for the weight and bias update rule for gradient descent.
# </div>
#
# After completing the code, run it to compare **your gradients** with the **ground-truth computed by PyTorch.** (There may be small differences that you shouldn't worry about, e.g. within 1e-6). Also, you can check the neuron's performance at the end of training.

# %%
# Initialize parameters
#     Although you will implement gradient descent manually, let's set requires_grad=True
#     anyway so PyTorch will track the gradient too, and we can compare your gradient with PyTorch's.
w = torch.randn(2, requires_grad=True) # [size 2] tensor
b = torch.randn(1, requires_grad=True) # [size 1] tensor

alpha = 0.05 # learning rate
nepochs = 5000 # number of epochs

track_error = []
verbose = True
for e in range(nepochs): # for each epoch
    error_epoch = 0. # sum loss across the epoch
    perm = np.random.permutation(N)
    for p in perm: # visit data points in random order
        x_pat = X[p,:] # get one input pattern
        
        # compute output of neuron
        net = torch.dot(x_pat,w)+b
        yhat = g_logistic(net)
        
        # compute loss
        y = Y_or[p]
        myloss = loss(yhat,y)
        error_epoch += myloss.item()
        
        # Compute the gradient manually
        if verbose:
            print('Compute the gradient manually')
            print_forward(x_pat,yhat,y)
        with torch.no_grad():
            w_grad = 2 * (yhat-y) * g_logistic(net) * (1-(g_logistic(net))) * x_pat
            b_grad = 2 * (yhat-y) * g_logistic(net) * (1-(g_logistic(net))) 
            # TODO : YOUR GRADIENT CODE GOES HERE
            #  two lines of the form
            #    w_grad = ...    ([size 2] PyTorch tensor)
            #    b_grad = ...    ([size 1] PyTorch tensor)
            #  make sure to inclose your code in the "with torch.no_grad()" wrapper,
            #   otherwise PyTorch will try to track the "gradient" of the gradient computation, which we don't want.         
#            raise Exception('Replace with your code.')                      
        if verbose: print_grad(w_grad.numpy(),b_grad.numpy())

        # Compute the gradient with PyTorch and compre with manual values
        if verbose: print('Compute the gradient using PyTorch .backward()')
        myloss.backward()
        if verbose:
            print_grad(w.grad.numpy(),b.grad.numpy())
            print("")
        w.grad.zero_() # clear PyTorch's gradient
        b.grad.zero_()
        
        # Parameter update with gradient descent
        with torch.no_grad():
            w -= alpha * w_grad
            b -= alpha * b_grad
            # TODO : YOUR PARAMETER UPDATE CODE GOES HERE
            #  two lines of the form:
            #    w -=   ....
            #    b -=   ....
#            raise Exception('Replace with your code.')
            
    if verbose==True: verbose=False
    track_error.append(error_epoch)
    if e % 50 == 0:
        print("epoch " + str(e) + "; error=" +str(round(error_epoch,3)))

# print a final pass through patterns
for p in range(X.shape[0]):
    x_pat = X[p]
    net = torch.dot(x_pat,w)+b
    yhat = g_logistic(net)
    y = Y_or[p]
    print("Final result:")
    print_forward(x_pat,yhat,y)
    print("")
    
# track output of gradient descent
plt.figure()
plt.clf()
plt.plot(track_error)
plt.title('stochastic gradient descent (logistic activation)')
plt.ylabel('error for epoch')
plt.xlabel('epoch')
plt.show()
# Out:
# Compute the gradient manually
#  Input: [0. 1.]
#  Output: 0.293
#  Target: 1.0
#   d_loss / d_w = [-0.        -0.2928987]
#   d_loss / d_b = [-0.2928987]
# Compute the gradient using PyTorch .backward()
#   d_loss / d_w = [-0.        -0.2928987]
#   d_loss / d_b = [-0.2928987]
#
# Compute the gradient manually
#  Input: [0. 0.]
#  Output: 0.481
#  Target: 0.0
#   d_loss / d_w = [0. 0.]
#   d_loss / d_b = [0.24029861]
# Compute the gradient using PyTorch .backward()
#   d_loss / d_w = [0. 0.]
#   d_loss / d_b = [0.24029861]
#
# Compute the gradient manually
#  Input: [1. 1.]
#  Output: 0.44
#  Target: 1.0
#   d_loss / d_w = [-0.27601004 -0.27601004]
#   d_loss / d_b = [-0.27601004]
# Compute the gradient using PyTorch .backward()
#   d_loss / d_w = [-0.27601 -0.27601]
#   d_loss / d_b = [-0.27601]
#
# Compute the gradient manually
#  Input: [1. 0.]
#  Output: 0.637
#  Target: 1.0
#   d_loss / d_w = [-0.16778491 -0.        ]
#   d_loss / d_b = [-0.16778491]
# Compute the gradient using PyTorch .backward()
#   d_loss / d_w = [-0.16778488  0.        ]
#   d_loss / d_b = [-0.16778488]
#
# epoch 0; error=1.177
# epoch 50; error=0.554
# epoch 100; error=0.448
# epoch 150; error=0.375
# epoch 200; error=0.318
# epoch 250; error=0.274
# epoch 300; error=0.238
# epoch 350; error=0.21
# epoch 400; error=0.187
# epoch 450; error=0.168
# epoch 500; error=0.152
# epoch 550; error=0.138
# epoch 600; error=0.127
# epoch 650; error=0.117
# epoch 700; error=0.108
# epoch 750; error=0.1
# epoch 800; error=0.094
# epoch 850; error=0.088
# epoch 900; error=0.082
# epoch 950; error=0.077
# epoch 1000; error=0.073
# epoch 1050; error=0.069
# epoch 1100; error=0.066
# epoch 1150; error=0.062
# epoch 1200; error=0.059
# epoch 1250; error=0.057
# epoch 1300; error=0.054
# epoch 1350; error=0.052
# epoch 1400; error=0.05
# epoch 1450; error=0.048
# epoch 1500; error=0.046
# epoch 1550; error=0.044
# epoch 1600; error=0.043
# epoch 1650; error=0.041
# epoch 1700; error=0.04
# epoch 1750; error=0.039
# epoch 1800; error=0.037
# epoch 1850; error=0.036
# epoch 1900; error=0.035
# epoch 1950; error=0.034
# epoch 2000; error=0.033
# epoch 2050; error=0.032
# epoch 2100; error=0.031
# epoch 2150; error=0.03
# epoch 2200; error=0.03
# epoch 2250; error=0.029
# epoch 2300; error=0.028
# epoch 2350; error=0.027
# epoch 2400; error=0.027
# epoch 2450; error=0.026
# epoch 2500; error=0.026
# epoch 2550; error=0.025
# epoch 2600; error=0.024
# epoch 2650; error=0.024
# epoch 2700; error=0.023
# epoch 2750; error=0.023
# epoch 2800; error=0.022
# epoch 2850; error=0.022
# epoch 2900; error=0.022
# epoch 2950; error=0.021
# epoch 3000; error=0.021
# epoch 3050; error=0.02
# epoch 3100; error=0.02
# epoch 3150; error=0.02
# epoch 3200; error=0.019
# epoch 3250; error=0.019
# epoch 3300; error=0.019
# epoch 3350; error=0.018
# epoch 3400; error=0.018
# epoch 3450; error=0.018
# epoch 3500; error=0.017
# epoch 3550; error=0.017
# epoch 3600; error=0.017
# epoch 3650; error=0.017
# epoch 3700; error=0.016
# epoch 3750; error=0.016
# epoch 3800; error=0.016
# epoch 3850; error=0.016
# epoch 3900; error=0.015
# epoch 3950; error=0.015
# epoch 4000; error=0.015
# epoch 4050; error=0.015
# epoch 4100; error=0.015
# epoch 4150; error=0.014
# epoch 4200; error=0.014
# epoch 4250; error=0.014
# epoch 4300; error=0.014
# epoch 4350; error=0.014
# epoch 4400; error=0.013
# epoch 4450; error=0.013
# epoch 4500; error=0.013
# epoch 4550; error=0.013
# epoch 4600; error=0.013
# epoch 4650; error=0.013
# epoch 4700; error=0.012
# epoch 4750; error=0.012
# epoch 4800; error=0.012
# epoch 4850; error=0.012
# epoch 4900; error=0.012
# epoch 4950; error=0.012
# Final result:
#  Input: [0. 0.]
#  Output: 0.081
#  Target: 0.0
#
# Final result:
#  Input: [0. 1.]
#  Output: 0.95
#  Target: 1.0
#
# Final result:
#  Input: [1. 0.]
#  Output: 0.95
#  Target: 1.0
#
# Final result:
#  Input: [1. 1.]
#  Output: 1.0
#  Target: 1.0

# %%
print("learned weight: ", w)
print("bias: ", b)
# Out:
# learned weight:  tensor([5.3679, 5.3671], requires_grad=True)
# bias:  tensor([-2.4287], requires_grad=True)

# %% [markdown]
# Now let's change the activation function to "linear" (identity function) from the "logistic" function, such that $g(\textbf{net}) = \textbf{net}$. With a linear rather than logistic activation, the output will no longer be constrained between 0 and 1. The artificial neuron will still try to solve the problem with 0/1 targets. Here is the simple implementation of $g(\cdot)$:

# %%
def g_linear(x):
    return x

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <h3> Problem 3 (5 points) </h3>
# <br>
# Just as before, fill in the missing code fragments for implementing gradient descent. This time we are using the linear activation function. Be sure to change your gradient calculation to reflect the new activation function.
# </div>

# %%
# Initialize parameters
#     Although you will implement gradient descent manually, let's set requires_grad=True
#     anyway so PyTorch will track the gradient too, and we can compare your gradient with PyTorch's.
w = torch.randn(2, requires_grad=True) # [size 2] tensor
b = torch.randn(1, requires_grad=True) # [size 1] tensor

alpha = 0.05 # learning rate
nepochs = 5000 # number of epochs

track_error = []
verbose = True
for e in range(nepochs): # for each epoch
    error_epoch = 0. # sum loss across the epoch
    perm = np.random.permutation(N)
    for p in perm: # visit data points in random order
        x_pat = X[p,:] # get one input pattern
        
        # compute output of neuron
        net = torch.dot(x_pat,w)+b
        yhat = g_linear(net)
        
        # compute loss
        y = Y_or[p]
        myloss = loss(yhat,y)
        error_epoch += myloss.item()
        
        # Compute the gradient manually
        if verbose:
            print('Compute the gradient manually')
            print_forward(x_pat,yhat,y)
        with torch.no_grad():
            w_grad = 2 * (yhat-y) * x_pat
            b_grad = 2 * (yhat-y)
            # TODO : YOUR GRADIENT CODE GOES HERE
            #  two lines of the form
            #    w_grad = ...    ([size 2] PyTorch tensor)
            #    b_grad = ...    ([size 1] PyTorch tensor)
            #  make sure to inclose your code in the "with torch.no_grad()" wrapper,
            #   otherwise PyTorch will try to track the "gradient" of the gradient computation, which we don't want.         
#            raise Exception('Replace with your code.')                      
        if verbose: print_grad(w_grad.numpy(),b_grad.numpy())

        # Compute the gradient with PyTorch and compre with manual values
        if verbose: print('Compute the gradient using PyTorch .backward()')
        myloss.backward()
        if verbose:
            print_grad(w.grad.numpy(),b.grad.numpy())
            print("")
        w.grad.zero_() # clear PyTorch's gradient
        b.grad.zero_()
        
        # Parameter update with gradient descent
        with torch.no_grad():
            w -= alpha * w_grad
            b -= alpha * b_grad
            # TODO : YOUR PARAMETER UPDATE CODE GOES HERE
            #  two lines of the form:
            #    w -=   ....
            #    b -=   ....
#            raise Exception('Replace with your code.')
            
    if verbose==True: verbose=False
    track_error.append(error_epoch)
    if e % 50 == 0:
        print("epoch " + str(e) + "; error=" +str(round(error_epoch,3)))

# print a final pass through patterns
for p in range(X.shape[0]):
    x_pat = X[p]
    net = torch.dot(x_pat,w)+b
    yhat = g_linear(net)
    y = Y_or[p]
    print("Final result:")
    print_forward(x_pat,yhat,y)
    print("")
    
# track output of gradient descent
plt.figure()
plt.clf()
plt.plot(track_error)
plt.title('stochastic gradient descent (linear/null activation)')
plt.ylabel('error for epoch')
plt.xlabel('epoch')
plt.show()
# Out:
# Compute the gradient manually
#  Input: [0. 1.]
#  Output: 0.242
#  Target: 1.0
#   d_loss / d_w = [-0.        -1.5155523]
#   d_loss / d_b = [-1.5155523]
# Compute the gradient using PyTorch .backward()
#   d_loss / d_w = [-0.        -1.5155523]
#   d_loss / d_b = [-1.5155523]
#
# Compute the gradient manually
#  Input: [0. 0.]
#  Output: -1.614
#  Target: 0.0
#   d_loss / d_w = [-0. -0.]
#   d_loss / d_b = [-3.2289636]
# Compute the gradient using PyTorch .backward()
#   d_loss / d_w = [0. 0.]
#   d_loss / d_b = [-3.2289636]
#
# Compute the gradient manually
#  Input: [1. 0.]
#  Output: -1.691
#  Target: 1.0
#   d_loss / d_w = [-5.382736 -0.      ]
#   d_loss / d_b = [-5.382736]
# Compute the gradient using PyTorch .backward()
#   d_loss / d_w = [-5.382736  0.      ]
#   d_loss / d_b = [-5.382736]
#
# Compute the gradient manually
#  Input: [1. 1.]
#  Output: 0.855
#  Target: 1.0
#   d_loss / d_w = [-0.2896669 -0.2896669]
#   d_loss / d_b = [-0.2896669]
# Compute the gradient using PyTorch .backward()
#   d_loss / d_w = [-0.2896669 -0.2896669]
#   d_loss / d_b = [-0.2896669]
#
# epoch 0; error=10.445
# epoch 50; error=0.307
# epoch 100; error=0.304
# epoch 150; error=0.305
# epoch 200; error=0.308
# epoch 250; error=0.308
# epoch 300; error=0.309
# epoch 350; error=0.306
# epoch 400; error=0.309
# epoch 450; error=0.308
# epoch 500; error=0.299
# epoch 550; error=0.305
# epoch 600; error=0.298
# epoch 650; error=0.308
# epoch 700; error=0.304
# epoch 750; error=0.307
# epoch 800; error=0.306
# epoch 850; error=0.303
# epoch 900; error=0.304
# epoch 950; error=0.308
# epoch 1000; error=0.297
# epoch 1050; error=0.307
# epoch 1100; error=0.308
# epoch 1150; error=0.3
# epoch 1200; error=0.308
# epoch 1250; error=0.307
# epoch 1300; error=0.306
# epoch 1350; error=0.308
# epoch 1400; error=0.307
# epoch 1450; error=0.308
# epoch 1500; error=0.307
# epoch 1550; error=0.3
# epoch 1600; error=0.306
# epoch 1650; error=0.308
# epoch 1700; error=0.307
# epoch 1750; error=0.306
# epoch 1800; error=0.307
# epoch 1850; error=0.308
# epoch 1900; error=0.296
# epoch 1950; error=0.3
# epoch 2000; error=0.305
# epoch 2050; error=0.309
# epoch 2100; error=0.3
# epoch 2150; error=0.305
# epoch 2200; error=0.306
# epoch 2250; error=0.307
# epoch 2300; error=0.308
# epoch 2350; error=0.308
# epoch 2400; error=0.308
# epoch 2450; error=0.3
# epoch 2500; error=0.308
# epoch 2550; error=0.299
# epoch 2600; error=0.302
# epoch 2650; error=0.303
# epoch 2700; error=0.301
# epoch 2750; error=0.303
# epoch 2800; error=0.307
# epoch 2850; error=0.3
# epoch 2900; error=0.305
# epoch 2950; error=0.302
# epoch 3000; error=0.311
# epoch 3050; error=0.308
# epoch 3100; error=0.308
# epoch 3150; error=0.3
# epoch 3200; error=0.301
# epoch 3250; error=0.307
# epoch 3300; error=0.304
# epoch 3350; error=0.3
# epoch 3400; error=0.301
# epoch 3450; error=0.306
# epoch 3500; error=0.309
# epoch 3550; error=0.31
# epoch 3600; error=0.307
# epoch 3650; error=0.308
# epoch 3700; error=0.306
# epoch 3750; error=0.307
# epoch 3800; error=0.3
# epoch 3850; error=0.308
# epoch 3900; error=0.311
# epoch 3950; error=0.302
# epoch 4000; error=0.307
# epoch 4050; error=0.308
# epoch 4100; error=0.297
# epoch 4150; error=0.307
# epoch 4200; error=0.304
# epoch 4250; error=0.302
# epoch 4300; error=0.305
# epoch 4350; error=0.303
# epoch 4400; error=0.302
# epoch 4450; error=0.298
# epoch 4500; error=0.307
# epoch 4550; error=0.305
# epoch 4600; error=0.306
# epoch 4650; error=0.307
# epoch 4700; error=0.305
# epoch 4750; error=0.301
# epoch 4800; error=0.305
# epoch 4850; error=0.302
# epoch 4900; error=0.304
# epoch 4950; error=0.296
# Final result:
#  Input: [0. 0.]
#  Output: 0.252
#  Target: 0.0
#
# Final result:
#  Input: [0. 1.]
#  Output: 0.726
#  Target: 1.0
#
# Final result:
#  Input: [1. 0.]
#  Output: 0.733
#  Target: 1.0
#
# Final result:
#  Input: [1. 1.]
#  Output: 1.207
#  Target: 1.0

# %%
print("learned weight: ",w)
print("bias: ",b)
# Out:
# learned weight:  tensor([0.4805, 0.4740], requires_grad=True)
# bias:  tensor([0.2523], requires_grad=True)

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <h3> Problem 4 (10 points) </h3>
# <br>
# You'll see above that the artificial neuron, with the simple linear (identity) activation, does worse on the OR problem. Examine the learned weights and bias, and explain why the network does not arrive at a perfect solution.
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <strong>Q4 Answer</strong><br>
# From the simple linear activation, the learned weight we have is [0.4805, 0.4740], the bias we have is [0.2523].
# The nerwork does not arrive at a perfect solution because OR problem is aiming at binary classification problem, while our linear activation function we have seems trying to separate all positive and negative cases, including cases larger than 1. Since Linear activation can only have continuous output, it may not able to separate all the binary cases in the OR problem.
# </div>

# %% [markdown]
# In the next part, we have a simple multi-layer network with two input neurons, one hidden neuron, and one output neuron. Both the hidden and output unit should use the logistic activation function. We will learn to compute logical XOR. The network and logical XOR are shown below, for inputs $x_0$ and $x_1$ and target output $y$.
#
# <img src="images/nn_XOR.jpeg" style="width: 500px;"/>

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <h3> Problem 5 (15 points) </h3>
# <br>
# You will implement backpropagation for this simple network. In the code below, you have several parts to fill in. First, define the forward pass to compute the output `yhat` from the input `x`. Second, fill in code to manually compute the gradients for all five weights w and two biases b in closed form. Third, fill in the code for updating the biases and weights.
# </div>
#
# After completing the code, run it to compare **your gradients** with the **ground-truth computed by PyTorch.** (There may be small differences that you shouldn't worry about, e.g. within 1e-6). Also, you can check the network's performance at the end of training.

# %%
# Same input tensor X and new labels y for xor
Y_xor = torch.tensor([0.,1.,1.,0.])
N = X.shape[0] # number of input patterns

# Initialize parameters
#     Although you will implement gradient descent manually, let's set requires_grad=True
#     anyway so PyTorch will track the gradient too, and we can compare your gradient with PyTorch's.
w_34 = torch.randn(2,requires_grad=True) # [size 2] tensor representing [w_3,w_4]
w_012 = torch.randn(3,requires_grad=True) # [size 3] tensor representing [w_0,w_1,w_2]
b_0 = torch.randn(1,requires_grad=True) # [size 1] tensor
b_1 = torch.randn(1,requires_grad=True) # [size 1] tensor

alpha = 0.05 # learning rate
nepochs = 10000 # number of epochs

track_error = []
verbose = True
for e in range(nepochs): # for each epoch
    error_epoch = 0. # sum loss across the epoch
    perm = np.random.permutation(N)
    for p in perm: # visit data points in random order
        x_pat = X[p,:] # input pattern
        net_h = torch.dot(x_pat,w_34)+b_0
        h = g_logistic(net_h)
        
        # Compute the output of hidden neuron h
        # e.g., two lines like the following
        #  net_h = ...
        #  h = ...
        # TODO : YOUR CODE GOES HERE
#        raise Exception('Replace with your code.')                  

        #xh = (x_pat,net_h)
        net_y = torch.dot(torch.cat((x_pat,h)),w_012)+b_1
        yhat = g_logistic(net_y)
        
        # Compute the output of neuron yhat
        # e.g., two lines like the following
        #  net_y = ...
        #  yhat = ...
        # TODO : YOUR CODE GOES HERE
#        raise Exception('Replace with your code.')                     
        
        # compute loss
        y = Y_xor[p]
        myloss = loss(yhat,y)
        error_epoch += myloss.item()
        
        # print output if this is the last epoch
        if (e == nepochs-1):
            print("Final result:")
            print_forward(x_pat,yhat,y)
            print("")

        # Compute the gradient manually
        if verbose:
            print('Compute the gradient manually')
            print_forward(x_pat,yhat,y)
        with torch.no_grad():
            w_34_grad = 2 * (yhat-y) * yhat * (1-yhat) * w_012[2] * h * (1-h) * x_pat 
            b_0_grad = 2 * (yhat-y) * yhat * (1-yhat) * w_012[2] * h * (1-h)
            w_012_grad = 2 * (yhat-y) * yhat * (1-yhat) * torch.cat((x_pat,h))
            b_1_grad = 2 * (yhat-y) * yhat * (1-yhat)
            # TODO : YOUR GRADIENT CODE GOES HERE
            #  should include at least these 4 lines (helper lines may be useful)
            #    w_34_grad = ...  
            #    b_0_grad = ...
            #    w_012_grad = ...
            #    b_1_grad = ...
            #  make sure to inclose your code in the "with torch.no_grad()" wrapper,
            #   otherwise PyTorch will try to track the "gradient" of the gradient computation, which we don't want.
#            raise Exception('Replace with your code.')                      
        if verbose:
            print(" Grad for w_34 and b_0")
            print_grad(w_34_grad.numpy(),b_0_grad.numpy())
            print(" Grad for w_012 and b_1")
            print_grad(w_012_grad.numpy(),b_1_grad.numpy())
            print("")

        # Compute the gradient with PyTorch and compre with manual values
        if verbose: print('Compute the gradient using PyTorch .backward()')
        myloss.backward()
        if verbose:
            print(" Grad for w_34 and b_0")
            print_grad(w_34.grad.numpy(),b_0.grad.numpy())
            print(" Grad for w_012 and b_1")
            print_grad(w_012.grad.numpy(),b_1.grad.numpy())
            print("")
        w_34.grad.zero_() # clear PyTorch's gradient
        b_0.grad.zero_()
        w_012.grad.zero_()
        b_1.grad.zero_()
        
        # Parameter update with gradient descent
        with torch.no_grad():
            w_34 -= alpha * w_34_grad
            b_0 -= alpha * b_0_grad
            w_012 -= alpha * w_012_grad
            b_1 -= alpha * b_1_grad
            # TODO : YOUR PARAMETER UPDATE CODE GOES HERE
            # Four lines of the form
            # w_34 -= ...
            # b_0 -= ...
            # w_012 -= ...
            # b_1 -= ...
#             raise Exception('Replace with your code.')
            
    if verbose==True: verbose=False
    track_error.append(error_epoch)
    if e % 50 == 0:
        print("epoch " + str(e) + "; error=" +str(round(error_epoch,3)))

# track output of gradient descent
plt.figure()
plt.clf()
plt.plot(track_error)
plt.title('stochastic gradient descent (XOR)')
plt.ylabel('error for epoch')
plt.xlabel('epoch')
plt.show()
# Out:
# Compute the gradient manually
#  Input: [1. 1.]
#  Output: 0.277
#  Target: 0.0
#  Grad for w_34 and b_0
#   d_loss / d_w = [-0.00235409 -0.00235409]
#   d_loss / d_b = [-0.00235409]
#  Grad for w_012 and b_1
#   d_loss / d_w = [0.11086777 0.11086777 0.01056834]
#   d_loss / d_b = [0.11086777]
#
# Compute the gradient using PyTorch .backward()
#  Grad for w_34 and b_0
#   d_loss / d_w = [-0.00235409 -0.00235409]
#   d_loss / d_b = [-0.00235409]
#  Grad for w_012 and b_1
#   d_loss / d_w = [0.11086777 0.11086777 0.01056834]
#   d_loss / d_b = [0.11086777]
#
# Compute the gradient manually
#  Input: [1. 0.]
#  Output: 0.289
#  Target: 1.0
#  Grad for w_34 and b_0
#   d_loss / d_w = [0.01794251 0.        ]
#   d_loss / d_b = [0.01794251]
#  Grad for w_012 and b_1
#   d_loss / d_w = [-0.29223084 -0.         -0.13611849]
#   d_loss / d_b = [-0.29223084]
#
# Compute the gradient using PyTorch .backward()
#  Grad for w_34 and b_0
#   d_loss / d_w = [0.01794251 0.        ]
#   d_loss / d_b = [0.01794251]
#  Grad for w_012 and b_1
#   d_loss / d_w = [-0.29223084  0.         -0.13611849]
#   d_loss / d_b = [-0.29223084]
#
# Compute the gradient manually
#  Input: [0. 1.]
#  Output: 0.249
#  Target: 1.0
#  Grad for w_34 and b_0
#   d_loss / d_w = [0.         0.00978542]
#   d_loss / d_b = [0.00978542]
#  Grad for w_012 and b_1
#   d_loss / d_w = [-0.         -0.28079796 -0.0495129 ]
#   d_loss / d_b = [-0.28079796]
#
# Compute the gradient using PyTorch .backward()
#  Grad for w_34 and b_0
#   d_loss / d_w = [0.         0.00978542]
#   d_loss / d_b = [0.00978542]
#  Grad for w_012 and b_1
#   d_loss / d_w = [ 0.         -0.28079796 -0.0495129 ]
#   d_loss / d_b = [-0.28079796]
#
# Compute the gradient manually
#  Input: [0. 0.]
#  Output: 0.263
#  Target: 0.0
#  Grad for w_34 and b_0
#   d_loss / d_w = [-0. -0.]
#   d_loss / d_b = [-0.00557786]
#  Grad for w_012 and b_1
#   d_loss / d_w = [0.         0.         0.06506481]
#   d_loss / d_b = [0.10182434]
#
# Compute the gradient using PyTorch .backward()
#  Grad for w_34 and b_0
#   d_loss / d_w = [0. 0.]
#   d_loss / d_b = [-0.00557786]
#  Grad for w_012 and b_1
#   d_loss / d_w = [0.        0.        0.0650648]
#   d_loss / d_b = [0.10182433]
#
# epoch 0; error=1.215
# epoch 50; error=1.029
# epoch 100; error=1.02
# epoch 150; error=1.017
# epoch 200; error=1.014
# epoch 250; error=1.013
# epoch 300; error=1.011
# epoch 350; error=1.009
# epoch 400; error=1.007
# epoch 450; error=1.005
# epoch 500; error=1.002
# epoch 550; error=0.999
# epoch 600; error=0.995
# epoch 650; error=0.99
# epoch 700; error=0.984
# epoch 750; error=0.977
# epoch 800; error=0.969
# epoch 850; error=0.959
# epoch 900; error=0.947
# epoch 950; error=0.935
# epoch 1000; error=0.921
# epoch 1050; error=0.905
# epoch 1100; error=0.888
# epoch 1150; error=0.869
# epoch 1200; error=0.849
# epoch 1250; error=0.828
# epoch 1300; error=0.806
# epoch 1350; error=0.782
# epoch 1400; error=0.758
# epoch 1450; error=0.733
# epoch 1500; error=0.707
# epoch 1550; error=0.681
# epoch 1600; error=0.655
# epoch 1650; error=0.63
# epoch 1700; error=0.604
# epoch 1750; error=0.579
# epoch 1800; error=0.555
# epoch 1850; error=0.531
# epoch 1900; error=0.508
# epoch 1950; error=0.486
# epoch 2000; error=0.465
# epoch 2050; error=0.445
# epoch 2100; error=0.426
# epoch 2150; error=0.407
# epoch 2200; error=0.39
# epoch 2250; error=0.374
# epoch 2300; error=0.358
# epoch 2350; error=0.343
# epoch 2400; error=0.329
# epoch 2450; error=0.316
# epoch 2500; error=0.303
# epoch 2550; error=0.291
# epoch 2600; error=0.28
# epoch 2650; error=0.27
# epoch 2700; error=0.26
# epoch 2750; error=0.25
# epoch 2800; error=0.241
# epoch 2850; error=0.233
# epoch 2900; error=0.225
# epoch 2950; error=0.217
# epoch 3000; error=0.21
# epoch 3050; error=0.203
# epoch 3100; error=0.197
# epoch 3150; error=0.191
# epoch 3200; error=0.185
# epoch 3250; error=0.179
# epoch 3300; error=0.174
# epoch 3350; error=0.169
# epoch 3400; error=0.164
# epoch 3450; error=0.16
# epoch 3500; error=0.155
# epoch 3550; error=0.151
# epoch 3600; error=0.147
# epoch 3650; error=0.143
# epoch 3700; error=0.139
# epoch 3750; error=0.136
# epoch 3800; error=0.133
# epoch 3850; error=0.129
# epoch 3900; error=0.126
# epoch 3950; error=0.123
# epoch 4000; error=0.121
# epoch 4050; error=0.118
# epoch 4100; error=0.115
# epoch 4150; error=0.113
# epoch 4200; error=0.11
# epoch 4250; error=0.108
# epoch 4300; error=0.106
# epoch 4350; error=0.103
# epoch 4400; error=0.101
# epoch 4450; error=0.099
# epoch 4500; error=0.097
# epoch 4550; error=0.096
# epoch 4600; error=0.094
# epoch 4650; error=0.092
# epoch 4700; error=0.09
# epoch 4750; error=0.089
# epoch 4800; error=0.087
# epoch 4850; error=0.085
# epoch 4900; error=0.084
# epoch 4950; error=0.083
# epoch 5000; error=0.081
# epoch 5050; error=0.08
# epoch 5100; error=0.078
# epoch 5150; error=0.077
# epoch 5200; error=0.076
# epoch 5250; error=0.075
# epoch 5300; error=0.073
# epoch 5350; error=0.072
# epoch 5400; error=0.071
# epoch 5450; error=0.07
# epoch 5500; error=0.069
# epoch 5550; error=0.068
# epoch 5600; error=0.067
# epoch 5650; error=0.066
# epoch 5700; error=0.065
# epoch 5750; error=0.064
# epoch 5800; error=0.063
# epoch 5850; error=0.062
# epoch 5900; error=0.062
# epoch 5950; error=0.061
# epoch 6000; error=0.06
# epoch 6050; error=0.059
# epoch 6100; error=0.058
# epoch 6150; error=0.058
# epoch 6200; error=0.057
# epoch 6250; error=0.056
# epoch 6300; error=0.056
# epoch 6350; error=0.055
# epoch 6400; error=0.054
# epoch 6450; error=0.053
# epoch 6500; error=0.053
# epoch 6550; error=0.052
# epoch 6600; error=0.052
# epoch 6650; error=0.051
# epoch 6700; error=0.05
# epoch 6750; error=0.05
# epoch 6800; error=0.049
# epoch 6850; error=0.049
# epoch 6900; error=0.048
# epoch 6950; error=0.048
# epoch 7000; error=0.047
# epoch 7050; error=0.047
# epoch 7100; error=0.046
# epoch 7150; error=0.046
# epoch 7200; error=0.045
# epoch 7250; error=0.045
# epoch 7300; error=0.044
# epoch 7350; error=0.044
# epoch 7400; error=0.043
# epoch 7450; error=0.043
# epoch 7500; error=0.042
# epoch 7550; error=0.042
# epoch 7600; error=0.042
# epoch 7650; error=0.041
# epoch 7700; error=0.041
# epoch 7750; error=0.04
# epoch 7800; error=0.04
# epoch 7850; error=0.04
# epoch 7900; error=0.039
# epoch 7950; error=0.039
# epoch 8000; error=0.039
# epoch 8050; error=0.038
# epoch 8100; error=0.038
# epoch 8150; error=0.038
# epoch 8200; error=0.037
# epoch 8250; error=0.037
# epoch 8300; error=0.037
# epoch 8350; error=0.036
# epoch 8400; error=0.036
# epoch 8450; error=0.036
# epoch 8500; error=0.035
# epoch 8550; error=0.035
# epoch 8600; error=0.035
# epoch 8650; error=0.034
# epoch 8700; error=0.034
# epoch 8750; error=0.034
# epoch 8800; error=0.034
# epoch 8850; error=0.033
# epoch 8900; error=0.033
# epoch 8950; error=0.033
# epoch 9000; error=0.033
# epoch 9050; error=0.032
# epoch 9100; error=0.032
# epoch 9150; error=0.032
# epoch 9200; error=0.032
# epoch 9250; error=0.031
# epoch 9300; error=0.031
# epoch 9350; error=0.031
# epoch 9400; error=0.031
# epoch 9450; error=0.03
# epoch 9500; error=0.03
# epoch 9550; error=0.03
# epoch 9600; error=0.03
# epoch 9650; error=0.029
# epoch 9700; error=0.029
# epoch 9750; error=0.029
# epoch 9800; error=0.029
# epoch 9850; error=0.029
# epoch 9900; error=0.028
# epoch 9950; error=0.028
# Final result:
#  Input: [0. 1.]
#  Output: 0.913
#  Target: 1.0
#
# Final result:
#  Input: [1. 0.]
#  Output: 0.913
#  Target: 1.0
#
# Final result:
#  Input: [0. 0.]
#  Output: 0.059
#  Target: 0.0
#
# Final result:
#  Input: [1. 1.]
#  Output: 0.097
#  Target: 0.0

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <h3> Problem 6 (10 points) </h3>
# <br>
# After running your XOR network, print the values of the learned weights and biases. Your job now is to describe the solution that the network has learned. How does it work? Walk through each input pattern to describe how the network computes the right answer (if it does). See discussion in lecture for an example.
# </div>

# %%
print(w_012)
print(w_34)
print(b_0)
print(b_1)
# Out:
# tensor([ -4.7184,  -4.7202, -10.7804], requires_grad=True)
# tensor([-6.8661, -6.8776], requires_grad=True)
# tensor([2.5257], requires_grad=True)
# tensor([7.2043], requires_grad=True)

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <strong>Q6 Answer</strong><br>
# The learned weights value is w_012: [ -4.7184,  -4.7202, -10.7804], w_34[-6.8661, -6.8776]. The bias is b_0: [2.5257], b_1: [7.2043]. By the weight_34, and b_0 we can calculate the hidden unit. From the hidden unit, weight_012, and b_1, we can have our predict y. From the input values, we can calculate the weighted sum, then, adding the bias. The net value would be used for the activation function. Then, we would have our output. By repeating this process, weights and biases were being adjusted towards lower error.
#
# Using formulas provided above, we can calculate all cases as listed below:
#
# Pattern 1 : [0. 1.]: net_h = -9.4033, h = 1.00008, net_y = -22.70576243, yhat = 0.913, y = 1.0
#
# Pattern 2 : [1. 0.]: net_h = -9.3918, h = 1.00008, net_y = -22.70396243, yhat = 0.913, y = 1.0
#
# Pattern 3 : [0. 0.]: net_h = -2.5257, h = 1.08695, net_y = -18.92205578, yhat = 0.059, y = 0.0
#
# Pattern 4 : [1. 1.]: net_h = -16.2694, h = 1, net_y = -27.4233, yhat = 0.097, y = 0.0
# </div>

# %% [markdown]
# YOUR RESPONSE GOES HERE
